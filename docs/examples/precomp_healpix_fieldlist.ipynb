# %% [markdown]
# ## Precomputed: regridding HEALPix GRIB fieldlist

# %% [raw]
# This example shows how to interpolate GRIB data defined on a HEALPix nested grid using the :ref:`precomputed <precomputed-regrid-high>` backend. We will also see how to inspect and plot the resulting data and how to convert it to xarray.
#
# To make this notebook work :xref:`earthkit-data` and :xref:`earthkit-plots` have to be installed. The data will be represented as an `earthkit-data GRIB FieldList <https://earthkit-data.readthedocs.io/en/latest/guide/data_format/grib.html>`_.

# %% [markdown]
# #### Regridding

# %% [raw]
# We perform the regridding with the :ref:`regrid() <precomputed-regrid-high>` method.

# %%
from earthkit.geo.regrid import regrid
from earthkit.data import from_source

# Get HEALPix nested GRIB data containing two fields.
ds = from_source("sample", "H8_nested_t2.grib2")

# the target grid is a global 5x5 degree regular latitude-longitude grid
out_grid = {"grid": [5,5]}

# perform interpolation for each field and add results 
# to a new fieldlist stored in memory
r = regrid(ds, grid=out_grid, interpolation="linear", backend="precomputed")

d = r.data()
lat = d[0]
lon = d[1]
vals = d[2:]
lat.shape, lon.shape, vals.shape
# Out:
# H8_nested_t2.grib2:   0%|          | 0.00/4.82k [00:00<?, ?B/s]
# ((37, 72), (37, 72), (2, 37, 72))

# %% [raw]
# Please note that regridding with the :ref:`precomputed <precomputed-regrid>` backend only works between a predefined set of global grids. See the :ref:`precomputed_inventory` for details.

# %% [markdown]
# #### Plotting the results

# %%
import earthkit.plots as ekp

ekp.quickplot(r).show()
# Out:
# /Users/cgr/git/earthkit-plots/src/earthkit/plots/quickplot.py:138: UserWarning: Failed to execute quickplot on given data with:
# Field.metadata() missing 1 required positional argument: 'keys'
#
# consider constructing the plot manually.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import earthkit.plots as ekp
# ----> 3 ekp.quickplot(r).show()
#
# File ~/git/earthkit-plots/src/earthkit/plots/quickplot.py:143, in quickplot(rows, columns, domain, crs, methods, mode, groupby, units, subplot_titles, combine_vectors, *args, **kwargs)
#     137     except Exception as err:
#     138         warnings.warn(
#     139             f"Failed to execute {methods[i]} on given data with: \n"
#     140             f"{err}\n\n"
#     141             "consider constructing the plot manually."
#     142         )
# --> 143         raise err
#     145 for m in schema.quickmap_subplot_workflow:
#     146     args = []
#
# File ~/git/earthkit-plots/src/earthkit/plots/quickplot.py:136, in quickplot(rows, columns, domain, crs, methods, mode, groupby, units, subplot_titles, combine_vectors, *args, **kwargs)
#     134 unit = units[i]
#     135 try:
# --> 136     getattr(subplot, methods[i])(group_args, units=unit, **kwargs)
#     137 except Exception as err:
#     138     warnings.warn(
#     139         f"Failed to execute {methods[i]} on given data with: \n"
#     140         f"{err}\n\n"
#     141         "consider constructing the plot manually."
#     142     )
#
# File ~/git/earthkit-plots/src/earthkit/plots/components/subplots.py:690, in Subplot.quickplot(self, data, style, units, **kwargs)
#     688 source = get_source(data)
#     689 if style is None:
# --> 690     auto_style = auto.guess_style(source, units=units, **kwargs)
#     691     if auto_style is not None:
#     692         method = getattr(self, auto_style._preferred_method)
#
# File ~/git/earthkit-plots/src/earthkit/plots/styles/auto.py:66, in guess_style(data, units, **kwargs)
#      48 """
#      49 Guess the style to be applied to the data based on its metadata.
#      50
#    (...)     63     will be adjusted accordingly.
#      64 """
#      65 if units is None:
# ---> 66     units = data.units
#      68 if not schema.automatic_styles or schema.style_library is None:
#      69     return styles.DEFAULT_STYLE
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/__init__.py:642, in Source.units(self)
#     640     return self.y.units
#     641 else:
# --> 642     if self.z is not None:
#     643         return self.z.units
#     644     return None
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/__init__.py:437, in Source.z(self)
#     434 if self._z_dimension is not None:
#     435     return self._z_dimension
# --> 437 self._extract()
#     439 # For vector fields, compute magnitude lazily
#     440 if self._u_coord_info is not None and self._v_coord_info is not None:
#     441     # Compute magnitude from u and v components
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/__init__.py:178, in Source._extract(self)
#     176 # Apply regridding if needed
#     177 if self._should_regrid and self._z_coord_info is not None:
# --> 178     gridspec = self._extractor.get_gridspec()
#     179     if gridspec is not None and gridspec.name not in GRIDSPECS_TO_NOT_REGRID:
#     180         from earthkit.plots.sources.regrid import apply_regrid
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/extractors/earthkit.py:308, in EarthkitExtractor.get_gridspec(self)
#     305 from earthkit.plots.sources.gridspec import get_grid_spec
#     307 try:
# --> 308     return get_grid_spec(self.data)
#     309 except (AttributeError, ImportError):
#     310     return None
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/gridspec.py:326, in GridSpecAccessor.__call__(self, data)
#     324 def __call__(self, data):
#     325     if self.has_grid:
# --> 326         return GridSpec.from_data(data)
#     327     else:
#     328         return LegacyGridSpec.from_data(data)
#
# File ~/git/earthkit-plots/src/earthkit/plots/sources/gridspec.py:243, in GridSpec.from_data(data)
#     241     gs = data.grid_spec
#     242 else:
# --> 243     md = data.metadata()
#     244     if hasattr(md, "grid_spec"):
#     245         gs = md.grid_spec
#
# TypeError: Field.metadata() missing 1 required positional argument: 'keys'

# %% [markdown]
# #### Converting the results to xarray

# %%
r.to_xarray()

# %% [markdown]
# #### Writing the results to disk

# %% [markdown]
# Write the resulting fieldlist to disk:

# %%
out_file = "_res_H8_nested_to_5x5.grib"
r.to_target("file", out_file)
